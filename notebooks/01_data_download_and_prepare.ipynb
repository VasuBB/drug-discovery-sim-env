# %% [markdown]
# # 01 - Download Local Data and Prepare Snapshots

# %%
# !python -m pip install -e .[training,test]

# %%
# !python -m drug_discovery_env.scripts.download_local_data --compound-limit 5000 --pubmed-per-query 250

# %%
# !python -m drug_discovery_env.scripts.prepare_snapshots
