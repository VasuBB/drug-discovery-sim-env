# %% [markdown]
# # 03 - Reproducible Training and Evaluation

# %%
# !python -m drug_discovery_env.scripts.run_local_rollout --data-mode local_only

# %%
# !python -m drug_discovery_env.scripts.run_evaluation --episodes 5 --data-mode local_only

# %%
# !python -m drug_discovery_env.scripts.run_training_experiment --episodes 2 --data-mode local_only --device auto --model sshleifer/tiny-gpt2 --max-train-steps 10 --out-dir artifacts/training
